# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('appendix.csv',encoding='utf-8')

# %% [raw]
# Edx 在线数据说明：
#
# 共有290个在线课堂数据，字段信息23个，可大致分为4类：
# 1、课程相关字段：
# Institution（online course holders）课程持有机构
# Course number(the unique id of each course) 课程编号ID
# Launch date上线日期
# Course title课程名称
# Instructors讲师
# Course subject课程主题
# Honor code certificates是否提供认证，有（1）没有（0）
# Year课程持续时间
#
# 2、数量相关字段：
# Total course hours总课程时长小时数
# Paticipants学生数
# Certified 拿到认证人数
# Median hours for certification 拿到认证小时数的中位数
# Audited （50% course content accessed）完成 50%课程人数
#
# 3、百分比相关字段：
# %audited 完成 50%课程人数占比
# %certified 认证人数占比
# %certified of > 50% course content accessed 认证人数在完成 50%课程人数中占比
# %play video 播放视频人数占比
# % posted in forum 粘贴到论坛占比
# %grade higher than zero分数高于0的百分比
#
#
# 4、学员信息相关字段：
# Median age用户年龄中位数
# %male男性占比
# %female女性占比
# %bachelor’s degree or higher用户学士学历或以上占比

# %%
data.head()
data.shape  # 290条数据，23个字段
# Out:
# (290, 23)

# %%
data.columns
# Out:
# Index(['Institution', 'Course Number', 'Launch Date', 'Course Title',
#        'Instructors', 'Course Subject', 'Year', 'Honor Code Certificates',
#        'Participants (Course Content Accessed)',
#        'Audited (> 50% Course Content Accessed)', 'Certified', '% Audited',
#        '% Certified', '% Certified of > 50% Course Content Accessed',
#        '% Played Video', '% Posted in Forum', '% Grade Higher Than Zero',
#        'Total Course Hours (Thousands)', 'Median Hours for Certification',
#        'Median Age', '% Male', '% Female', '% Bachelor's Degree or Higher'],
#       dtype='object')

# %%
# 课程主题   290条数据，共有4大课程主题
number_=data['Course Subject'].value_counts()
number_.shape
number_
# Out:
# Humanities, History, Design, Religion, and Education    94
# Science, Technology, Engineering, and Mathematics       91
# Government, Health, and Social Science                  75
# Computer Science                                        30
# Name: Course Subject, dtype: int64

# %%
data.sort_values(by="Course Subject",inplace = True) 
data.head()
# Out:
#     Institution Course Number Launch Date  \
# 221    HarvardX         CS50x  01/01/2016
# 126        MITx      6.004.1x  03/03/2015
# 41         MITx       6.00.1x  02/19/2014
# 261        MITx    21W.789.4x  04/25/2016
# 270        MITx    21W.789.5x  05/23/2016
#
#                                           Course Title  \
# 221            Introduction to Computer Science (2016)
# 126           Computation Structures: Digital Circuits
# 41    Introduction to Computer Science and Programming
# 261  Mobile Application Experiences: Understanding Use
# 270  Mobile Application Experiences: Reporting Rese...
#
#                                           Instructors    Course Subject  Year  \
# 221                                               NaN  Computer Science     4
# 126  Chris Terman, Steve Ward, Silvina Hanono Wachman  Computer Science     3
# 41                          Eric Grimson, John Guttag  Computer Science     2
# ...
